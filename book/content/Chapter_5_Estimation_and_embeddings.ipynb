# %% [markdown]
# ## 6. More advanced topics: Bootstrap sampling, estimating the network and network embeddings
#
# Covers
#
# * Bootstrap network metrics
# * Confidence intervals
# * Hypothesis testing
# * Embeddings (eigendecomposition, node2vec, graph2vec)
